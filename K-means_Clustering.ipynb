# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=300, n_features=2, 
                           centers=8, cluster_std=1.8,random_state=101)
data[0].shape
# Out:
# (300, 2)

# %%
data[1]
# Out:
# array([2, 3, 0, 5, 7, 6, 6, 2, 3, 1, 1, 6, 5, 3, 0, 0, 3, 6, 2, 5, 0, 1,
#        1, 2, 3, 6, 2, 7, 2, 0, 1, 5, 5, 0, 2, 7, 0, 0, 5, 4, 3, 2, 7, 1,
#        3, 1, 6, 4, 6, 1, 7, 3, 6, 4, 4, 1, 5, 0, 1, 5, 2, 2, 7, 1, 6, 3,
#        2, 7, 5, 2, 6, 1, 4, 2, 7, 5, 5, 4, 5, 4, 5, 3, 4, 6, 4, 1, 4, 3,
#        1, 1, 3, 0, 6, 7, 4, 7, 2, 7, 2, 1, 6, 2, 0, 2, 0, 0, 2, 5, 6, 7,
#        3, 3, 6, 2, 0, 0, 1, 5, 5, 7, 7, 1, 4, 0, 4, 4, 2, 2, 1, 0, 7, 6,
#        4, 7, 6, 6, 5, 5, 7, 2, 0, 0, 1, 6, 4, 7, 4, 7, 4, 2, 5, 4, 4, 7,
#        4, 5, 1, 3, 7, 6, 2, 7, 3, 6, 7, 2, 7, 2, 0, 7, 1, 0, 0, 5, 1, 6,
#        3, 3, 4, 0, 0, 7, 3, 4, 5, 4, 3, 1, 1, 5, 5, 0, 4, 3, 3, 1, 4, 5,
#        3, 5, 6, 5, 0, 4, 0, 5, 6, 4, 0, 4, 4, 0, 5, 6, 7, 6, 1, 3, 7, 2,
#        5, 1, 0, 6, 2, 1, 3, 6, 1, 3, 5, 4, 7, 7, 6, 1, 4, 6, 6, 6, 1, 0,
#        0, 3, 0, 4, 7, 2, 1, 4, 7, 1, 3, 6, 3, 7, 1, 3, 4, 1, 5, 2, 0, 0,
#        1, 3, 6, 3, 0, 2, 3, 7, 3, 2, 5, 2, 2, 2, 5, 4, 0, 7, 5, 5, 6, 2,
#        7, 5, 3, 0, 3, 6, 2, 4, 7, 6, 3, 3, 2, 1])

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='brg')

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.12305806, -2.85490465],
#        [ 4.04372134,  6.41966347],
#        [ 9.73524602, -5.75037094],
#        [-6.55984647,  5.62461987],
#        [-9.54197109, -6.61775175],
#        [ 4.62596156, -6.04169047],
#        [-0.28949681,  2.73923711],
#        [-3.26612255,  9.09609278]])

# %%
kmeans.labels_
# Out:
# array([1, 3, 6, 5, 2, 3, 3, 1, 7, 4, 4, 3, 0, 3, 6, 0, 6, 3, 1, 5, 6, 4,
#        4, 1, 7, 3, 1, 2, 6, 6, 4, 5, 0, 6, 1, 2, 6, 6, 0, 5, 7, 1, 2, 4,
#        3, 4, 3, 5, 3, 4, 2, 6, 3, 5, 5, 4, 0, 6, 4, 0, 1, 1, 2, 4, 3, 7,
#        1, 2, 0, 1, 3, 4, 5, 1, 2, 0, 5, 5, 0, 0, 0, 7, 5, 3, 5, 4, 5, 7,
#        4, 4, 3, 6, 3, 2, 5, 5, 1, 2, 1, 4, 6, 1, 6, 1, 6, 1, 1, 0, 3, 2,
#        3, 7, 3, 1, 6, 6, 4, 5, 0, 2, 2, 4, 5, 6, 5, 5, 1, 1, 4, 6, 2, 3,
#        5, 2, 3, 3, 0, 0, 2, 1, 6, 6, 4, 3, 0, 2, 5, 2, 5, 1, 0, 2, 5, 2,
#        5, 0, 4, 7, 2, 3, 1, 2, 7, 3, 2, 6, 2, 1, 6, 2, 4, 6, 6, 0, 4, 3,
#        3, 3, 0, 6, 6, 2, 7, 5, 5, 5, 7, 4, 4, 5, 0, 6, 5, 7, 3, 4, 0, 0,
#        3, 0, 3, 0, 6, 5, 6, 0, 3, 5, 6, 5, 5, 0, 0, 3, 2, 3, 4, 7, 5, 1,
#        0, 4, 6, 3, 1, 4, 7, 3, 4, 7, 0, 5, 2, 2, 3, 4, 5, 7, 3, 3, 4, 6,
#        6, 7, 6, 5, 2, 1, 4, 5, 2, 4, 7, 6, 7, 2, 4, 7, 5, 4, 0, 1, 6, 6,
#        4, 3, 3, 7, 6, 1, 7, 5, 3, 1, 0, 7, 1, 1, 5, 5, 6, 2, 0, 0, 7, 1,
#        2, 0, 7, 6, 7, 7, 1, 2, 2, 6, 7, 7, 1, 4])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='brg')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='brg')
